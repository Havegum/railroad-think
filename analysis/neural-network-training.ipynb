# %%
import pandas as pd

# %%
import os

# %%
df = pd.read_csv('../src/mcts/heuristics/nn/training_data.csv', header=None)
df.columns = ['board', 'move', 'score']
df.board = df.board.fillna('')

# %%
df.score.max
# Out:
# <Axes: >
